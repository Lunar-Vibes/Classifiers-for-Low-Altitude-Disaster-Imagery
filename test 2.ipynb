# %%
from datasets import load_dataset
ds = load_dataset("MITLL/LADI-v2-dataset")
# Out:
# ...
# Loading dataset shards:   0%|          | 0/40 [00:00<?, ?it/s]

# %%
ds["train"][20]
# Out:
# {'image': <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1798x1200>,
#  'bridges_any': False,
#  'buildings_any': True,
#  'buildings_affected_or_greater': False,
#  'buildings_minor_or_greater': False,
#  'debris_any': True,
#  'flooding_any': False,
#  'flooding_structures': False,
#  'roads_any': True,
#  'roads_damage': False,
#  'trees_any': True,
#  'trees_damage': True,
#  'water_any': False}

# %%
ds["train"][4]["image"]
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1800x1200>
